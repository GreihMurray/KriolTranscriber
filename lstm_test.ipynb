# %% [markdown]
# <a href="https://colab.research.google.com/github/GreihMurray/KriolTranscriber/blob/master/lstm_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install evaluate
# !pip install jiwer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting evaluate
#   Downloading evaluate-0.3.0-py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 611 kB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from evaluate) (1.21.6)
# Collecting xxhash
#   Downloading xxhash-3.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 9.8 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from evaluate) (21.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from evaluate) (1.3.5)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.8/dist-packages (from evaluate) (4.64.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 52.0 MB/s
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from evaluate) (2.23.0)
# Collecting datasets>=2.0.0
#   Downloading datasets-2.7.1-py3-none-any.whl (451 kB)
#      |████████████████████████████████| 451 kB 52.0 MB/s
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting huggingface-hub>=0.7.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 48.8 MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.8/dist-packages (from evaluate) (0.3.6)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.8/dist-packages (from evaluate) (2022.11.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets>=2.0.0->evaluate) (3.8.3)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets>=2.0.0->evaluate) (9.0.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.7.0->evaluate) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->evaluate) (3.0.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->evaluate) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->evaluate) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->evaluate) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->evaluate) (2022.9.24)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 24.1 MB/s
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->evaluate) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->evaluate) (1.15.0)
# Installing collected packages: urllib3, xxhash, responses, multiprocess, huggingface-hub, datasets, evaluate
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.7.1 evaluate-0.3.0 huggingface-hub-0.11.1 multiprocess-0.70.14 responses-0.18.0 urllib3-1.25.11 xxhash-3.1.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jiwer
#   Downloading jiwer-2.5.1-py3-none-any.whl (15 kB)
# Collecting levenshtein==0.20.2
#   Downloading Levenshtein-0.20.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 5.4 MB/s
# Collecting rapidfuzz<3.0.0,>=2.3.0
#   Downloading rapidfuzz-2.13.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 28.1 MB/s
# Installing collected packages: rapidfuzz, levenshtein, jiwer
# Successfully installed jiwer-2.5.1 levenshtein-0.20.2 rapidfuzz-2.13.3

# %%
from keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from keras.utils.vis_utils import plot_model
import tensorflow as tf
from tensorflow.keras import activations
import numpy as np
import itertools
from scipy.io import wavfile
from evaluate import load
from keras import backend as K
from tensorflow.keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional, Reshape, GRU, Flatten, Activation

# %%
import math, random
import torch
import torchaudio
from torchaudio import transforms
import pandas as pd
from tqdm import tqdm
import os
import unicodedata
import re

from keras.models import load_model

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
DEFAULT_DIR = '/content/gdrive/MyDrive/Colab_Notebooks/NLP/project/'
SR = 44100

# %%
def load_html_data(dir_ext):
    all_data = []
    chars_to_replace = '.,;:<>?/\'\\[]()!#$%"”“'
    directory = DEFAULT_DIR + 'html/' + dir_ext + '/'

    dir_files = sorted(os.listdir(directory))

    for file in tqdm(dir_files, desc='Loading HTML Data'):
        file = directory + file
        divs = []
        with open(file, 'r', encoding='UTF-8') as in_file:
            data = ' '.join(in_file.readlines())
            data = unicodedata.normalize('NFC', data)
            data = re.sub(r'<span class=.*?</span>', '', data)
            data = re.sub(r'<a.*?</a>', '', data)
            data = data.replace(u'\xa0', u' ')
            check_divs = re.findall(r'<div class=\'mt\'.*?>(.*?) </div>', data)
            check_divs.extend(re.findall(r'<div class=\'mt2\'.*?>(.*?) </div>', data))
            # print(data)
            check_divs.extend(re.findall(r'<div class=\'ip\'>(.*)', data))

            if len(check_divs) > 0:
                full = '!'.join(check_divs)
                full = re.sub(r'[\,,@,#,$,%,^,&,*,(,),\[,\],\',\",;,:,“,”,‘,’]', '', full)
                full = re.sub('^\s+', ' ', full).strip('\u00A0')
                full = re.split('[\.,\?,!,\n]', str(full))
                all_data.extend([s.strip() for s in full])

            divs.extend(re.findall(r'<div class=\'[p,s]\'.*?>(.*?) </div>', data))

        full_data = '!'.join(divs)
        full_data = re.sub(r'[\,,@,#,$,%,^,&,*,(,),\[,\],\',\",;,:,“,”,‘,’]', '', full_data)
        full_data = re.sub(' +', ' ', full_data)
        full_data = re.split('[\.,\?,!,\n]', str(full_data))

        all_data.extend([s.strip() for s in full_data])

        clean = []
        for row2 in all_data:
            if len(row2) >= 1:
                clean.append(row2.lower())

    return clean

# %%
def load_dataset(dir_ext):
    transcripts = load_html_data(dir_ext)
    all_x = []
    all_y = []
    directory = DEFAULT_DIR + 'audio/' + dir_ext + '/'

    order = []

    dir_files = sorted(os.listdir(directory))

    for i, file in tqdm(enumerate(dir_files), desc='Loading Audio Data & Creating Dataset'):
        file = directory + file
        
        sr, data = wavfile.read(file)

        max_len = SR//1000 * 15000

        if len(data) > max_len:
          continue

        all_x.append(data)
        all_y.append(transcripts[i])


    return pd.DataFrame(list(zip(all_x, all_y)), columns=['audio', 'transcription'])

# %%
def one_hot(data, test_data, map_use):
    mapping = {}
    mapped = []

    i = 0

    if not test_data:
        for sentence in data:
          cur_map = []
          for word in sentence:
              if word in mapping.keys():
                cur_map.append(mapping[word])
              else:
                i += 1
                cur_map.append(i)
                mapping[word] = i
                
          mapped.append(cur_map)
    else:
        for sentence in data:
          cur_map = []
          for word in sentence:
              if word in map_use.keys():
                cur_map.append(map_use[word])
              else:
                i += 1
                cur_map.append(i)
                map_use[word] = i
                
          mapped.append(cur_map)
      
    return mapped, mapping

# %%
def vectorize(data):
    vecs = []
    for row in data:
      cur_vec = [0] * len(row[0])
      for piece in row:
        piece = list(piece)
        cur_vec[piece.index(1)] += 1
      cur_vec[2] = 1
      vecs.append(cur_vec)

    return vecs

# %%
def pad_audio(data):
    max_len = SR//1000 * 15000

    for i, aud in tqdm(enumerate(data), desc='Padding audio'):
      if len(aud) < max_len:
        data[i] = np.array(np.append(aud, np.zeros(max_len - len(aud))))

    return data

# %%
def get_min(audio):
    minim = 0

    for row in tqdm(audio, desc='Finding min'):
        if min(row) < minim:
            minim = min(row)
    
    return minim

# %%
def get_max(audio):
    maxim = 0

    for row in tqdm(audio, desc='Finding max'):
        if max(row) > maxim:
           maxim = max(row)

    return maxim

# %%
def adjust_audio(audio, minim):
    for i, row in tqdm(enumerate(audio), desc='Adjusting Audio'):
        for j, val in enumerate(row):
            audio[i][j] = int(val + abs(minim))

    return audio

# %%
def advanced_relu(x):
    return K.relu(x, max_value=500000)

# %%
def build_model(input_len, output_len, maxim):
    model = Sequential()
    model.add(Dense(321, input_shape=(input_len,), activation=advanced_relu))
    model.add(Embedding(input_dim=499999, output_dim=34))
    model.add(Bidirectional(LSTM(units=50, return_sequences=True, recurrent_dropout=0.1)))
    model.add(Dense(34, activation='softmax'))
    #model.add(Reshape((321, 34)))
    
    model.compile(optimizer="adam", metrics=["accuracy"], loss='categorical_crossentropy')


    return model

# %%
def load_and_process_data(folder_path, test_data=False, map_use=None):
    df = load_dataset(folder_path)
    clean_y = list(df['transcription'])

    padded_y = list(zip(*itertools.zip_longest(*list(df['transcription']), fillvalue='!')))
    enc_y, mapping = one_hot(padded_y, test_data, map_use)
    cat_y = np.array(to_categorical(enc_y))

    padded_x = pad_audio(df['audio'])

    minim = get_min(padded_x)
    padded_x = adjust_audio(padded_x, minim)
    maxim = get_max(padded_x)

    padded_x = np.stack(padded_x)

    for entry in cat_y:
        for row in entry:
            if row[7] != 0:
                row[7] = 0

    return clean_y, cat_y, padded_x, minim, maxim, mapping

# %%
def evaluate(model, clean_y, padded_x, mapping):
    cur_words = []

    map_list = mapping.items()
    map_key = list(mapping.keys())

    last_char = False

    all_words = []

    preds = model.predict(padded_x)

    print(len(preds))

    for pred in preds:
        cur_words = []
        for row in pred:
            row = list(row)
            cur_words.append(map_key[row.index(max(row))-1])
            
        len_words = len(cur_words) - 1

        for i in range(len_words, 0, -1):
            if cur_words[i] != ' ':
                joined = ''.join(cur_words)
                all_words.append(re.sub(' +', ' ', joined))
                break
            else:
                cur_words.pop()

    cer = load('cer')
    cer_score = cer.compute(predictions=all_words, references=clean_y[:len(all_words)])
    print('Character Error Rate:', cer_score)

    wer = load('wer')
    wer_score = wer.compute(predictions=all_words, references=clean_y[:len(all_words)])
    print('Word Error Rate:', wer_score)

    return cer_score, wer_score

# %%
def multi_run():
    print('\033[95m' + 'LOADING TRAINING DATA\n')
    clean_y, cat_y, padded_x, minim, maxim, mapping = load_and_process_data('train')
    print('\n\n', '\033[95m' + 'LOADING TESTING DATA\n', sep='')
    y_test, _, x_test, _, _, _ = load_and_process_data('test', test_data=True, map_use=mapping)

    base_model_name = '/content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_500000_'

    all_metrics = []

    model = build_model(len(padded_x[0]), len(cat_y[0]), maxim)

    for i in range(5, 100, 5):
      model_name = base_model_name + str(i)
      model.fit(padded_x, cat_y, epochs=5, verbose=1, batch_size=1)

      cer, wer = evaluate(model, clean_y, padded_x, mapping)
      test_cer, test_wer = evaluate(model, y_test, x_test, mapping)

      all_metrics.append((i, (cer, wer), (test_cer, test_wer)))

      model.save(model_name)

    for row in all_metrics:
        print(row)

# %%
# BIG 

multi_run()
# Out:
# LOADING TRAINING DATA
# Loading HTML Data: 100%|██████████| 290/290 [00:02<00:00, 125.69it/s]
# Loading Audio Data & Creating Dataset: 0it [00:00, ?it/s]<ipython-input-7-6963f008061e>:14: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sr, data = wavfile.read(file)
# Loading Audio Data & Creating Dataset: 356it [00:01, 238.06it/s]
# Padding audio: 306it [00:02, 115.45it/s]
# Finding min: 100%|██████████| 306/306 [00:22<00:00, 13.68it/s]
# Adjusting Audio: 306it [10:52,  2.13s/it]
# Finding max: 100%|██████████| 306/306 [00:14<00:00, 21.12it/s]
# LOADING TESTING DATA
# Loading HTML Data: 100%|██████████| 3/3 [00:00<00:00,  5.29it/s]
# Loading Audio Data & Creating Dataset: 51it [00:10,  4.73it/s]
# Padding audio: 41it [00:00, 157.42it/s]
# Finding min: 100%|██████████| 41/41 [00:02<00:00, 19.21it/s]
# Adjusting Audio: 41it [01:23,  2.04s/it]
# Finding max: 100%|██████████| 41/41 [00:01<00:00, 20.71it/s]
# Epoch 1/5
# WARNING:tensorflow:Gradients do not exist for variables ['dense_4/kernel:0', 'dense_4/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_4/kernel:0', 'dense_4/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 306/306 [==============================] - 148s 470ms/step - loss: 0.8086 - accuracy: 0.0487
# Epoch 2/5
# 306/306 [==============================] - 145s 473ms/step - loss: 0.7844 - accuracy: 0.0497
# Epoch 3/5
# 306/306 [==============================] - 145s 473ms/step - loss: 0.7819 - accuracy: 0.0503
# Epoch 4/5
# 306/306 [==============================] - 149s 487ms/step - loss: 0.7805 - accuracy: 0.0503
# Epoch 5/5
# 306/306 [==============================] - 155s 507ms/step - loss: 0.7794 - accuracy: 0.0503
# 10/10 [==============================] - 4s 368ms/step
# 306
# Character Error Rate: 0.97747963584092
# Word Error Rate: 1.0
# 2/2 [==============================] - 1s 225ms/step
# 41
# Character Error Rate: 0.9554208273894437
# Word Error Rate: 1.0
# Epoch 1/5
# 306/306 [==============================] - 169s 550ms/step - loss: 0.7784 - accuracy: 0.0503
# Epoch 2/5
# 306/306 [==============================] - 150s 490ms/step - loss: 0.7778 - accuracy: 0.0503
# Epoch 3/5
# 306/306 [==============================] - 147s 480ms/step - loss: 0.7767 - accuracy: 0.0503
# Epoch 4/5
# 306/306 [==============================] - 147s 479ms/step - loss: 0.7759 - accuracy: 0.0503
# Epoch 5/5
# 306/306 [==============================] - 149s 487ms/step - loss: 0.7751 - accuracy: 0.0503
# 10/10 [==============================] - 4s 342ms/step
# 306
# Character Error Rate: 0.9777745014927574
# Word Error Rate: 1.0
# 2/2 [==============================] - 1s 214ms/step
# 41
# Character Error Rate: 0.9586305278174037
# Word Error Rate: 1.0
# Epoch 1/5
# 306/306 [==============================] - 148s 484ms/step - loss: 0.7751 - accuracy: 0.0503
# Epoch 2/5
# 306/306 [==============================] - 149s 488ms/step - loss: 0.7742 - accuracy: 0.0507
# Epoch 3/5
# 306/306 [==============================] - 158s 516ms/step - loss: 0.7735 - accuracy: 0.0507
# Epoch 4/5
# 306/306 [==============================] - 148s 484ms/step - loss: 0.7732 - accuracy: 0.0507
# Epoch 5/5
# 306/306 [==============================] - 146s 479ms/step - loss: 0.7729 - accuracy: 0.0507
# 10/10 [==============================] - 4s 367ms/step
# 306
# Character Error Rate: 0.9795436954037816
# Word Error Rate: 1.0
# 2/2 [==============================] - 1s 191ms/step
# 41
# Character Error Rate: 0.9661198288159771
# Word Error Rate: 1.0
# Epoch 1/5
# 306/306 [==============================] - 156s 510ms/step - loss: 0.7722 - accuracy: 0.0507
# Epoch 2/5
# 306/306 [==============================] - 156s 509ms/step - loss: 0.7717 - accuracy: 0.0507
# Epoch 3/5
# 306/306 [==============================] - 152s 498ms/step - loss: 0.7715 - accuracy: 0.0507
# Epoch 4/5
# 306/306 [==============================] - 148s 483ms/step - loss: 0.7712 - accuracy: 0.0507
# Epoch 5/5
# 306/306 [==============================] - 144s 470ms/step - loss: 0.7705 - accuracy: 0.0508
# 10/10 [==============================] - 3s 339ms/step
# 306
# Character Error Rate: 0.9793962625778629
# Word Error Rate: 1.0
# 2/2 [==============================] - 1s 202ms/step
# 41
# Character Error Rate: 0.9661198288159771
# Word Error Rate: 1.0
# Epoch 1/5
# 306/306 [==============================] - 156s 509ms/step - loss: 0.7704 - accuracy: 0.0508
# Epoch 2/5
# 306/306 [==============================] - 152s 498ms/step - loss: 0.7700 - accuracy: 0.0508
# Epoch 3/5
# 306/306 [==============================] - 152s 495ms/step - loss: 0.7696 - accuracy: 0.0508
# Epoch 4/5
# 306/306 [==============================] - 153s 500ms/step - loss: 0.7694 - accuracy: 0.0508
# Epoch 5/5
# 306/306 [==============================] - 157s 514ms/step - loss: 0.7689 - accuracy: 0.0508
# 10/10 [==============================] - 4s 420ms/step
# 306
# Character Error Rate: 0.9785116656223508
# Word Error Rate: 1.0
# 2/2 [==============================] - 1s 291ms/step
# 41
# Character Error Rate: 0.9661198288159771
# Word Error Rate: 1.0
# Epoch 1/5
# 306/306 [==============================] - 177s 576ms/step - loss: 0.7683 - accuracy: 0.0508
# Epoch 2/5
# 306/306 [==============================] - 146s 478ms/step - loss: 0.7600 - accuracy: 0.0580
# Epoch 3/5
# 306/306 [==============================] - 147s 480ms/step - loss: 0.7509 - accuracy: 0.0638
# Epoch 4/5
# 306/306 [==============================] - 145s 474ms/step - loss: 0.7445 - accuracy: 0.0650
# Epoch 5/5
# 306/306 [==============================] - 152s 498ms/step - loss: 0.7397 - accuracy: 0.0655
# 10/10 [==============================] - 4s 353ms/step
# 306
# Character Error Rate: 0.735136928237072
# Word Error Rate: 1.2657930764717387
# 2/2 [==============================] - 1s 221ms/step
# 41
# Character Error Rate: 1.912981455064194
# Word Error Rate: 5.06286836935167
# Epoch 1/5
# 306/306 [==============================] - 147s 480ms/step - loss: 0.7367 - accuracy: 0.0658
# Epoch 2/5
# 306/306 [==============================] - 146s 476ms/step - loss: 0.7338 - accuracy: 0.0659
# Epoch 3/5
# 306/306 [==============================] - 147s 481ms/step - loss: 0.7320 - accuracy: 0.0660
# Epoch 4/5
# 306/306 [==============================] - 152s 495ms/step - loss: 0.7296 - accuracy: 0.0663
# Epoch 5/5
# 306/306 [==============================] - 146s 477ms/step - loss: 0.7278 - accuracy: 0.0665
# 10/10 [==============================] - 4s 375ms/step
# 306
# Character Error Rate: 0.7280970107994545
# Word Error Rate: 1.3099941326031683
# 2/2 [==============================] - 1s 175ms/step
# 41
# Character Error Rate: 1.9365192582025677
# Word Error Rate: 5.104125736738704
# Epoch 1/5
# 306/306 [==============================] - 145s 472ms/step - loss: 0.7262 - accuracy: 0.0666
# Epoch 2/5
# 306/306 [==============================] - 141s 461ms/step - loss: 0.7248 - accuracy: 0.0667
# Epoch 3/5
# 306/306 [==============================] - 153s 500ms/step - loss: 0.7231 - accuracy: 0.0668
# Epoch 4/5
# 306/306 [==============================] - 141s 462ms/step - loss: 0.7218 - accuracy: 0.0669
# Epoch 5/5
# 306/306 [==============================] - 139s 453ms/step - loss: 0.7206 - accuracy: 0.0669
# 10/10 [==============================] - 3s 322ms/step
# 306
# Character Error Rate: 0.726806973572666
# Word Error Rate: 1.317426168589869
# 2/2 [==============================] - 1s 181ms/step
# 41
# Character Error Rate: 1.9379457917261056
# Word Error Rate: 5.106090373280943
# Epoch 1/5
# 306/306 [==============================] - 140s 458ms/step - loss: 0.7192 - accuracy: 0.0670
# Epoch 2/5
# 306/306 [==============================] - 148s 484ms/step - loss: 0.7178 - accuracy: 0.0670
# Epoch 3/5
# 306/306 [==============================] - 142s 464ms/step - loss: 0.7167 - accuracy: 0.0670
# Epoch 4/5
# 306/306 [==============================] - 139s 454ms/step - loss: 0.7155 - accuracy: 0.0671
# Epoch 5/5
# 306/306 [==============================] - 140s 458ms/step - loss: 0.7142 - accuracy: 0.0671
# 10/10 [==============================] - 4s 384ms/step
# 306
# Character Error Rate: 0.7269544063985847
# Word Error Rate: 1.3184040680618032
# 2/2 [==============================] - 1s 214ms/step
# 41
# Character Error Rate: 1.9372325249643367
# Word Error Rate: 5.106090373280943
# Epoch 1/5
# 306/306 [==============================] - 142s 462ms/step - loss: 0.7131 - accuracy: 0.0672
# Epoch 2/5
# 306/306 [==============================] - 142s 463ms/step - loss: 0.7119 - accuracy: 0.0677
# Epoch 3/5
# 306/306 [==============================] - 149s 486ms/step - loss: 0.7110 - accuracy: 0.0679
# Epoch 4/5
# 306/306 [==============================] - 143s 467ms/step - loss: 0.7099 - accuracy: 0.0685
# Epoch 5/5
# 306/306 [==============================] - 139s 454ms/step - loss: 0.7089 - accuracy: 0.0685
# 10/10 [==============================] - 4s 379ms/step
# 306
# Character Error Rate: 0.7261066676495521
# Word Error Rate: 1.3184040680618032
# 2/2 [==============================] - 1s 197ms/step
# 41
# Character Error Rate: 1.93830242510699
# Word Error Rate: 5.110019646365423
# Epoch 1/5
# 306/306 [==============================] - 143s 467ms/step - loss: 0.7079 - accuracy: 0.0689
# Epoch 2/5
# 306/306 [==============================] - 141s 461ms/step - loss: 0.7070 - accuracy: 0.0690
# Epoch 3/5
# 306/306 [==============================] - 145s 473ms/step - loss: 0.7060 - accuracy: 0.0692
# Epoch 4/5
# 306/306 [==============================] - 141s 460ms/step - loss: 0.7049 - accuracy: 0.0693
# Epoch 5/5
# 306/306 [==============================] - 150s 490ms/step - loss: 0.7042 - accuracy: 0.0693
# 10/10 [==============================] - 3s 336ms/step
# 306
# Character Error Rate: 0.7259223766171539
# Word Error Rate: 1.3185996479561901
# 2/2 [==============================] - 1s 213ms/step
# 41
# Character Error Rate: 1.9372325249643367
# Word Error Rate: 5.110019646365423
# Epoch 1/5
# 306/306 [==============================] - 147s 480ms/step - loss: 0.7032 - accuracy: 0.0693
# Epoch 2/5
# 306/306 [==============================] - 145s 473ms/step - loss: 0.7021 - accuracy: 0.0693
# Epoch 3/5
# 306/306 [==============================] - 148s 485ms/step - loss: 0.7014 - accuracy: 0.0693
# Epoch 4/5
# 306/306 [==============================] - 154s 503ms/step - loss: 0.7005 - accuracy: 0.0694
# Epoch 5/5
# 306/306 [==============================] - 144s 469ms/step - loss: 0.6997 - accuracy: 0.0696
# 10/10 [==============================] - 3s 331ms/step
# 306
# Character Error Rate: 0.7252957871069994
# Word Error Rate: 1.3182084881674163
# 2/2 [==============================] - 1s 181ms/step
# 41
# Character Error Rate: 1.9386590584878745
# Word Error Rate: 5.115913555992141
# Epoch 1/5
# 306/306 [==============================] - 150s 490ms/step - loss: 0.6988 - accuracy: 0.0696
# Epoch 2/5
# 306/306 [==============================] - 147s 480ms/step - loss: 0.6983 - accuracy: 0.0697
# Epoch 3/5
# 306/306 [==============================] - 149s 485ms/step - loss: 0.6972 - accuracy: 0.0699
# Epoch 4/5
# 306/306 [==============================] - 142s 463ms/step - loss: 0.6966 - accuracy: 0.0703
# Epoch 5/5
# 306/306 [==============================] - 142s 463ms/step - loss: 0.6955 - accuracy: 0.0715
# 10/10 [==============================] - 4s 359ms/step
# 306
# Character Error Rate: 0.7223102723821458
# Word Error Rate: 1.3180129082730296
# 2/2 [==============================] - 1s 189ms/step
# 41
# Character Error Rate: 1.9354493580599144
# Word Error Rate: 5.1178781925343815
# Epoch 1/5
# 306/306 [==============================] - 144s 470ms/step - loss: 0.6943 - accuracy: 0.0730
# Epoch 2/5
# 306/306 [==============================] - 150s 489ms/step - loss: 0.6936 - accuracy: 0.0738
# Epoch 3/5
# 306/306 [==============================] - 140s 456ms/step - loss: 0.6927 - accuracy: 0.0739
# Epoch 4/5
# 306/306 [==============================] - 141s 461ms/step - loss: 0.6919 - accuracy: 0.0744
# Epoch 5/5
# 306/306 [==============================] - 141s 460ms/step - loss: 0.6907 - accuracy: 0.0760
# 10/10 [==============================] - 3s 331ms/step
# 306
# Character Error Rate: 0.7157863698352438
# Word Error Rate: 1.3182084881674163
# 2/2 [==============================] - 1s 204ms/step
# 41
# Character Error Rate: 1.921540656205421
# Word Error Rate: 5.113948919449902
# Epoch 1/5
# 306/306 [==============================] - 152s 495ms/step - loss: 0.6900 - accuracy: 0.0774
# Epoch 2/5
# 306/306 [==============================] - 145s 473ms/step - loss: 0.6891 - accuracy: 0.0785
# Epoch 3/5
# 306/306 [==============================] - 143s 469ms/step - loss: 0.6884 - accuracy: 0.0807
# Epoch 4/5
# 306/306 [==============================] - 142s 463ms/step - loss: 0.6877 - accuracy: 0.0825
# Epoch 5/5
# 306/306 [==============================] - 143s 467ms/step - loss: 0.6865 - accuracy: 0.0832
# 10/10 [==============================] - 3s 334ms/step
# 306
# Character Error Rate: 0.7137960266853415
# Word Error Rate: 1.317230588695482
# 2/2 [==============================] - 1s 184ms/step
# 41
# Character Error Rate: 1.9001426533523538
# Word Error Rate: 5.115913555992141
# Epoch 1/5
# 306/306 [==============================] - 149s 485ms/step - loss: 0.6855 - accuracy: 0.0845
# Epoch 2/5
# 306/306 [==============================] - 140s 456ms/step - loss: 0.6844 - accuracy: 0.0848
# Epoch 3/5
# 306/306 [==============================] - 141s 461ms/step - loss: 0.6836 - accuracy: 0.0850
# Epoch 4/5
# 306/306 [==============================] - 143s 467ms/step - loss: 0.6830 - accuracy: 0.0854
# Epoch 5/5
# 306/306 [==============================] - 141s 459ms/step - loss: 0.6818 - accuracy: 0.0857
# 10/10 [==============================] - 3s 332ms/step
# 306
# Character Error Rate: 0.7102944970697725
# Word Error Rate: 1.3182084881674163
# 2/2 [==============================] - 1s 187ms/step
# 41
# Character Error Rate: 1.8944365192582027
# Word Error Rate: 5.1178781925343815
# Epoch 1/5
# 306/306 [==============================] - 147s 477ms/step - loss: 0.6810 - accuracy: 0.0858
# Epoch 2/5
# 306/306 [==============================] - 141s 459ms/step - loss: 0.6798 - accuracy: 0.0861
# Epoch 3/5
# 306/306 [==============================] - 140s 458ms/step - loss: 0.6787 - accuracy: 0.0873
# Epoch 4/5
# 306/306 [==============================] - 139s 456ms/step - loss: 0.6778 - accuracy: 0.0881
# Epoch 5/5
# 306/306 [==============================] - 140s 457ms/step - loss: 0.6767 - accuracy: 0.0883
# 10/10 [==============================] - 3s 326ms/step
# 306
# Character Error Rate: 0.723084294718219
# Word Error Rate: 1.3195775474281244
# 2/2 [==============================] - 1s 182ms/step
# 41
# Character Error Rate: 1.9372325249643367
# Word Error Rate: 5.12180746561886
# Epoch 1/5
# 306/306 [==============================] - 149s 489ms/step - loss: 0.6755 - accuracy: 0.0883
# Epoch 2/5
# 306/306 [==============================] - 139s 456ms/step - loss: 0.6744 - accuracy: 0.0884
# Epoch 3/5
# 306/306 [==============================] - 139s 455ms/step - loss: 0.6733 - accuracy: 0.0883
# Epoch 4/5
# 306/306 [==============================] - 144s 468ms/step - loss: 0.6725 - accuracy: 0.0885
# Epoch 5/5
# 306/306 [==============================] - 136s 445ms/step - loss: 0.6712 - accuracy: 0.0885
# 10/10 [==============================] - 3s 326ms/step
# 306
# Character Error Rate: 0.7258118019977148
# Word Error Rate: 1.3062781146098181
# 2/2 [==============================] - 1s 193ms/step
# 41
# Character Error Rate: 1.9554208273894436
# Word Error Rate: 5.111984282907662
# Epoch 1/5
# 306/306 [==============================] - 143s 468ms/step - loss: 0.6704 - accuracy: 0.0884
# Epoch 2/5
# 306/306 [==============================] - 136s 444ms/step - loss: 0.6693 - accuracy: 0.0885
# Epoch 3/5
# 306/306 [==============================] - 142s 463ms/step - loss: 0.6686 - accuracy: 0.0885
# Epoch 4/5
# 306/306 [==============================] - 139s 455ms/step - loss: 0.6674 - accuracy: 0.0885
# Epoch 5/5
# 306/306 [==============================] - 139s 454ms/step - loss: 0.6661 - accuracy: 0.0886
# 10/10 [==============================] - 3s 328ms/step
# 306
# Character Error Rate: 0.7245586229774059
# Word Error Rate: 1.3062781146098181
# 2/2 [==============================] - 1s 180ms/step
# 41
# Character Error Rate: 1.9158345221112696
# Word Error Rate: 5.115913555992141
# (5, (0.97747963584092, 1.0), (0.9554208273894437, 1.0))
# (10, (0.9777745014927574, 1.0), (0.9586305278174037, 1.0))
# (15, (0.9795436954037816, 1.0), (0.9661198288159771, 1.0))
# (20, (0.9793962625778629, 1.0), (0.9661198288159771, 1.0))
# (25, (0.9785116656223508, 1.0), (0.9661198288159771, 1.0))
# (30, (0.735136928237072, 1.2657930764717387), (1.912981455064194, 5.06286836935167))
# (35, (0.7280970107994545, 1.3099941326031683), (1.9365192582025677, 5.104125736738704))
# (40, (0.726806973572666, 1.317426168589869), (1.9379457917261056, 5.106090373280943))
# (45, (0.7269544063985847, 1.3184040680618032), (1.9372325249643367, 5.106090373280943))
# (50, (0.7261066676495521, 1.3184040680618032), (1.93830242510699, 5.110019646365423))
# (55, (0.7259223766171539, 1.3185996479561901), (1.9372325249643367, 5.110019646365423))
# (60, (0.7252957871069994, 1.3182084881674163), (1.9386590584878745, 5.115913555992141))
# (65, (0.7223102723821458, 1.3180129082730296), (1.9354493580599144, 5.1178781925343815))
# (70, (0.7157863698352438, 1.3182084881674163), (1.921540656205421, 5.113948919449902))
# (75, (0.7137960266853415, 1.317230588695482), (1.9001426533523538, 5.115913555992141))
# (80, (0.7102944970697725, 1.3182084881674163), (1.8944365192582027, 5.1178781925343815))
# (85, (0.723084294718219, 1.3195775474281244), (1.9372325249643367, 5.12180746561886))
# (90, (0.7258118019977148, 1.3062781146098181), (1.9554208273894436, 5.111984282907662))
# (95, (0.7245586229774059, 1.3062781146098181), (1.9158345221112696, 5.115913555992141))

# %%
#MAX (Should be 5,000,000)

multi_run()
# Out:
# LOADING TRAINING DATA
# Loading HTML Data: 100%|██████████| 290/290 [00:02<00:00, 116.91it/s]
# Loading Audio Data & Creating Dataset: 0it [00:00, ?it/s]<ipython-input-7-6963f008061e>:14: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sr, data = wavfile.read(file)
# Loading Audio Data & Creating Dataset: 356it [00:03, 100.11it/s]
# Padding audio: 306it [00:01, 162.67it/s]
# Finding min: 100%|██████████| 306/306 [00:14<00:00, 20.72it/s]
# Adjusting Audio: 306it [10:42,  2.10s/it]
# Finding max: 100%|██████████| 306/306 [00:14<00:00, 21.39it/s]
# LOADING TESTING DATA
# Loading HTML Data: 100%|██████████| 3/3 [00:00<00:00, 92.65it/s]
# Loading Audio Data & Creating Dataset: 51it [00:00, 70.58it/s]
# Padding audio: 41it [00:00, 148.94it/s]
# Finding min: 100%|██████████| 41/41 [00:03<00:00, 11.71it/s]
# Adjusting Audio: 41it [01:30,  2.21s/it]
# Finding max: 100%|██████████| 41/41 [00:01<00:00, 21.10it/s]
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_5
# 10/10 [==============================] - 4s 329ms/step
# 306
# Character Error Rate: 0.9805067429505517
# Word Error Rate: 1.0
# 2/2 [==============================] - 1s 178ms/step
# 41
# Character Error Rate: 0.9718259629101283
# Word Error Rate: 1.0
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_10
# 10/10 [==============================] - 4s 331ms/step
# 306
# Character Error Rate: 0.9723555702698229
# Word Error Rate: 0.9982475355969331
# 2/2 [==============================] - 1s 191ms/step
# 41
# Character Error Rate: 0.9625534950071327
# Word Error Rate: 1.0
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_15
# 10/10 [==============================] - 4s 337ms/step
# 306
# Character Error Rate: 0.9582760381880329
# Word Error Rate: 0.9950020824656394
# 2/2 [==============================] - 1s 186ms/step
# 41
# Character Error Rate: 0.9629101283880172
# Word Error Rate: 1.0
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_20
# 10/10 [==============================] - 4s 375ms/step
# 306
# Character Error Rate: 0.8887429150557411
# Word Error Rate: 0.9852707006369427
# 2/2 [==============================] - 1s 208ms/step
# 41
# Character Error Rate: 0.9561340941512125
# Word Error Rate: 1.0
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_25
# 10/10 [==============================] - 4s 356ms/step
# 306
# Character Error Rate: 0.7336625999778851
# Word Error Rate: 0.9649911989047526
# 2/2 [==============================] - 1s 239ms/step
# 41
# Character Error Rate: 0.8744650499286734
# Word Error Rate: 1.0098231827111985
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_30
# 10/10 [==============================] - 4s 328ms/step
# 306
# Character Error Rate: 0.6208027717371273
# Word Error Rate: 0.9518873459808331
# 2/2 [==============================] - 1s 186ms/step
# 41
# Character Error Rate: 0.8345221112696148
# Word Error Rate: 1.0491159135559922
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_35
# 10/10 [==============================] - 4s 337ms/step
# 306
# Character Error Rate: 0.5255980244001327
# Word Error Rate: 0.9313514570702132
# 2/2 [==============================] - 1s 191ms/step
# 41
# Character Error Rate: 0.8177603423680456
# Word Error Rate: 1.0628683693516698
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_40
# 10/10 [==============================] - 4s 341ms/step
# 306
# Character Error Rate: 0.45527256643691716
# Word Error Rate: 0.886368081361236
# 2/2 [==============================] - 1s 196ms/step
# 41
# Character Error Rate: 0.8366619115549215
# Word Error Rate: 1.0294695481335954
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_45
# 10/10 [==============================] - 4s 336ms/step
# 306
# Character Error Rate: 0.39523054808153035
# Word Error Rate: 0.8423626051241933
# 2/2 [==============================] - 1s 195ms/step
# 41
# Character Error Rate: 0.8388017118402282
# Word Error Rate: 1.037328094302554
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_50
# 10/10 [==============================] - 4s 330ms/step
# 306
# Character Error Rate: 0.354612804540931
# Word Error Rate: 0.7911206727948367
# 2/2 [==============================] - 1s 198ms/step
# 41
# Character Error Rate: 0.8684022824536377
# Word Error Rate: 1.0117878192534382
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_55
# 10/10 [==============================] - 4s 342ms/step
# 306
# Character Error Rate: 0.3162065533891121
# Word Error Rate: 0.7422256991981224
# 2/2 [==============================] - 1s 184ms/step
# 41
# Character Error Rate: 0.8587731811697575
# Word Error Rate: 1.0176817288801572
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_60
# 10/10 [==============================] - 4s 332ms/step
# 306
# Character Error Rate: 0.28830489108399987
# Word Error Rate: 0.7007627615881088
# 2/2 [==============================] - 1s 191ms/step
# 41
# Character Error Rate: 0.8816120906801007
# Word Error Rate: 1.0
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_65
# 10/10 [==============================] - 4s 324ms/step
# 306
# Character Error Rate: 0.287272861302569
# Word Error Rate: 0.6970467435947585
# 2/2 [==============================] - 1s 193ms/step
# 41
# Character Error Rate: 0.8819543509272468
# Word Error Rate: 1.005893909626719
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_70
# 10/10 [==============================] - 4s 337ms/step
# 306
# Character Error Rate: 0.25579595296892854
# Word Error Rate: 0.6379816154899276
# 2/2 [==============================] - 1s 211ms/step
# 41
# Character Error Rate: 0.8890870185449358
# Word Error Rate: 1.0
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_75
# 10/10 [==============================] - 4s 330ms/step
# 306
# Character Error Rate: 0.2535476023736685
# Word Error Rate: 0.6170545667905339
# 2/2 [==============================] - 1s 192ms/step
# 41
# Character Error Rate: 0.8894436519258203
# Word Error Rate: 1.0
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_80
# 10/10 [==============================] - 4s 329ms/step
# 306
# Character Error Rate: 0.23946776749843351
# Word Error Rate: 0.5865441032661842
# 2/2 [==============================] - 1s 206ms/step
# 41
# Character Error Rate: 0.8769614835948645
# Word Error Rate: 1.0019646365422397
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_85
# 10/10 [==============================] - 4s 340ms/step
# 306
# Character Error Rate: 0.2291106114776455
# Word Error Rate: 0.5783297477019362
# 2/2 [==============================] - 1s 201ms/step
# 41
# Character Error Rate: 0.8855206847360912
# Word Error Rate: 0.9980353634577603
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_90
# 10/10 [==============================] - 5s 339ms/step
# 306
# Character Error Rate: 0.22947919354244223
# Word Error Rate: 0.5599452376295717
# 2/2 [==============================] - 1s 257ms/step
# 41
# Character Error Rate: 0.8837375178316691
# Word Error Rate: 0.9960707269155207
#
#
#
# /content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_95
# 10/10 [==============================] - 11s 1s/step
# 306
# Character Error Rate: 0.19977147911982604
# Word Error Rate: 0.533541951887346
# 2/2 [==============================] - 1s 183ms/step
# 41
# Character Error Rate: 0.8708842027376988
# Word Error Rate: 1.0
#
#
#
# (5, (0.9805067429505517, 1.0), (0.9718259629101283, 1.0))
# (10, (0.9723555702698229, 0.9982475355969331), (0.9625534950071327, 1.0))
# (15, (0.9582760381880329, 0.9950020824656394), (0.9629101283880172, 1.0))
# (20, (0.8887429150557411, 0.9852707006369427), (0.9561340941512125, 1.0))
# (25, (0.7336625999778851, 0.9649911989047526), (0.8744650499286734, 1.0098231827111985))
# (30, (0.6208027717371273, 0.9518873459808331), (0.8345221112696148, 1.0491159135559922))
# (35, (0.5255980244001327, 0.9313514570702132), (0.8177603423680456, 1.0628683693516698))
# (40, (0.45527256643691716, 0.886368081361236), (0.8366619115549215, 1.0294695481335954))
# (45, (0.39523054808153035, 0.8423626051241933), (0.8388017118402282, 1.037328094302554))
# (50, (0.354612804540931, 0.7911206727948367), (0.8684022824536377, 1.0117878192534382))
# (55, (0.3162065533891121, 0.7422256991981224), (0.8587731811697575, 1.0176817288801572))
# (60, (0.28830489108399987, 0.7007627615881088), (0.8816120906801007, 1.0))
# (65, (0.287272861302569, 0.6970467435947585), (0.8819543509272468, 1.005893909626719))
# (70, (0.25579595296892854, 0.6379816154899276), (0.8890870185449358, 1.0))
# (75, (0.2535476023736685, 0.6170545667905339), (0.8894436519258203, 1.0))
# (80, (0.23946776749843351, 0.5865441032661842), (0.8769614835948645, 1.0019646365422397))
# (85, (0.2291106114776455, 0.5783297477019362), (0.8855206847360912, 0.9980353634577603))
# (90, (0.22947919354244223, 0.5599452376295717), (0.8837375178316691, 0.9960707269155207))
# (95, (0.19977147911982604, 0.533541951887346), (0.8708842027376988, 1.0))

# %%
def main(train=False, model=''):
    print('\033[95m' + 'LOADING TRAINING DATA\n')
    clean_y, cat_y, padded_x, minim, maxim, mapping = load_and_process_data('train')
    print('\n\n', '\033[95m' + 'LOADING TESTING DATA\n', sep='')
    y_test, _, x_test, _, _, _ = load_and_process_data('test', test_data=True, map_use=mapping)
    if train:
        # model = build_model(len(padded_x[0]), len(cat_y[0]), maxim)
        model = load_model(model)
        display(plot_model(model, show_shapes=True))

        model.fit(padded_x, cat_y, epochs=5, verbose=1, batch_size=1)

        model.save('/content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_10e')
    else:
        model = load_model(model)

    evaluate(model, y_test, x_test, mapping)
    print("train data")
    evaluate(model, clean_y, padded_x, mapping)

# %%
main(train=False, model='/content/gdrive/MyDrive/Colab_Notebooks/NLP/project/lstm_model_max_80')
# Out:
# LOADING TRAINING DATA
# Loading HTML Data: 100%|██████████| 290/290 [00:02<00:00, 134.23it/s]
# Loading Audio Data & Creating Dataset: 0it [00:00, ?it/s]<ipython-input-7-6963f008061e>:14: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sr, data = wavfile.read(file)
# Loading Audio Data & Creating Dataset: 356it [00:01, 337.67it/s]
# Padding audio: 306it [00:01, 235.15it/s]
# Finding min: 100%|██████████| 306/306 [00:14<00:00, 21.51it/s]
# Adjusting Audio: 306it [10:30,  2.06s/it]
# Finding max: 100%|██████████| 306/306 [00:14<00:00, 21.32it/s]
# LOADING TESTING DATA
# Loading HTML Data: 100%|██████████| 3/3 [00:00<00:00, 252.82it/s]
# Loading Audio Data & Creating Dataset: 51it [00:00, 138.63it/s]
# Padding audio: 41it [00:00, 121.69it/s]
# Finding min: 100%|██████████| 41/41 [00:02<00:00, 19.33it/s]
# Adjusting Audio: 41it [01:25,  2.07s/it]
# Finding max: 100%|██████████| 41/41 [00:01<00:00, 21.03it/s]
# 2/2 [==============================] - 2s 203ms/step
# 41
# Downloading builder script:   0%|          | 0.00/5.60k [00:00<?, ?B/s]
# Character Error Rate: 0.8769614835948645
# Downloading builder script:   0%|          | 0.00/4.49k [00:00<?, ?B/s]
# Word Error Rate: 1.0019646365422397
# train data
# 10/10 [==============================] - 3s 336ms/step
# 306
# Character Error Rate: 0.23946776749843351
# Word Error Rate: 0.5865441032661842

# %%
# 5 epochs CER - 0.9822 WER - 1.0
